# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeeveTD007/2026-FDP-DSU/blob/main/Day2_FDP_DSU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Scope of Variables

# %%
#Program 1: Local Variable
def display():
    x = 50
    print("Local Variable:", x)

display()

# %%
#program 2:Program 2: Global Variable
x = 100

def show():
    print("Inside Function:", x)

show()
print("Outside Function:", x)

# %%
#Program 3: Global Keyword
count = 0
def increment():
    global count
    count += 1
increment()
increment()
print(count)

# %% [markdown]
# # **Nonlocal and Namespaces**

# %%
#Program 4: Nonlocal Variable
def outer():
    number = 10
    def inner():
        nonlocal number
        number += 5
        print(number)
    inner()
outer()

# %% [markdown]
# //allows an inner function to access and modify a variable from its enclosing (outer) function.

# %%
#Program 5: globals()
name = "Python"

print(globals()["name"])

# %% [markdown]
# globals() returns a dictionary containing all global variables and functions in the program.

# %%
name = "Raj"
age = 25
city = "Chennai"

def update():
    globals()["name"] = "Rahul"
    globals()["age"] += 1
    globals()["city"] = "Bengaluru"
    print(globals())
update()

print(name)
print(age)
print(city)
print(globals())

# %%
#Program 6: locals()
def student():

    name = "John"
    age = 20

    print(locals())

student()

# %% [markdown]
# # **Classes and Objects**

# %% [markdown]
# Class
#
# Explanation: A class is a blueprint for creating objects. It defines the attributes (data) and methods (functions).
# Key: Template for objects.
#
# Object
#
# Explanation: An object is an instance of a class. It uses the properties and methods defined in the class.
# Key: Real-world instance of a class

# %%
#Program 7: Student Class
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks
    def display(self):
        print("Name:", self.name)
        print("Marks:", self.marks)
s1 = Student("Raj", 90)
s1.display()

# %%
#Program 8: Rectangle Class
class Rectangle:
    def __init__(self, length, breadth):
        self.length = length
        self.breadth = breadth
    def area(self):
        return self.length * self.breadth
r = Rectangle(10,5)
print("Area =", r.area())

# %%
#volume of sphere

# %%
#Program 9: Bank Account
class Bank:
    def __init__(self):
        self.balance = 1000
    def deposit(self, amount):
        self.balance += amount
    def display(self):
        print(self.balance)
b = Bank()
b.deposit(500)
b.display()

# %%
#withdrawal

# %% [markdown]
# **Inheritance**

# %%
#Program 10: Single Inheritance
class Animal:
    def sound(self):
        print("Animal Sound")
class Dog(Animal):
    def bark(self):
        print("Barking")
d = Dog()
d.sound()
d.bark()

# %%
#Program 11: Multilevel Inheritance
class A:
    def show(self):
        print("Class A")
class B(A):
    pass
class C(B):
    pass
obj = C()
obj.show()

# %%
#Program 12: Method Overriding
class Bird:
    def fly(self):
        print("Bird Flies")
class Sparrow(Bird):
    def fly(self):
        print("Sparrow Flies")
s = Sparrow()
s.fly()

# %% [markdown]
# **Exception** **Handling**

# %%
#Program 13: Division Example
try:
    a = int(input("A: "))
    b = int(input("B: "))
    print(a / b)
except ZeroDivisionError:
    print("Cannot divide by zero")

# %%
#withdrawal

# %%
#Program 14: Multiple Exceptions
try:
    numbers = [10,20]
    print(numbers[5])
except IndexError:
    print("Index Error")
except Exception as e:
    print(e)

# %%
numbers = [10,20]
print(numbers[5])

# %%
#Program 15: Finally Block
try:
    print(10/2)

finally:

    print("Program Completed")

# %% [markdown]
# **User-Defined Exception & Mini Project**

# %%
#Program 16: User-Defined Exception
class InvalidAge(Exception):
    pass
try:
    age = int(input("Age: "))
    if age < 18:
        raise InvalidAge("Not Eligible")
    print("Eligible")
except InvalidAge as e:
    print(e)

# %%
#Program 17: ATM Withdrawal
class LowBalance(Exception):
    pass

balance = 5000

try:

    amount = int(input("Withdraw Amount: "))

    if amount > balance:
        raise LowBalance("Insufficient Balance")

    balance -= amount

    print("Remaining Balance:", balance)

except LowBalance as e:

    print(e)

# %%
#Program 18: Student Result System (Mini Project)
class Student:

    def __init__(self, name, marks):

        self.name = name
        self.marks = marks

    def result(self):

        if self.marks >= 50:
            print("Pass")
        else:
            print("Fail")

s = Student("Raj", 65)

print("Student:", s.name)

s.result()

# %%
#raise
age = -6

if age < 0:
    raise ValueError("Age cannot be negative")

print("Valid Age")

# %%
#finally
try:
    number = int(input("Enter a number: "))
    result = 100 / number
    print("Result:", result)

except ZeroDivisionError:
    print("Cannot divide by zero")

finally:
    print("Program Ended")

# %%
#assert
marks = 35

assert marks >= 40, "Student has failed"

print("Student Passed")
